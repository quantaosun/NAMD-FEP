# %% [markdown]
# This notebook provide you a way to obtain a csv file for later QSAR building

# %%
import pandas as pd

# %% [markdown]
# Read structure

# %%
df = pd.read_csv('copy_dat.csv')

# %%
df
# Out:
#      Residue   Location Internal Unnamed: 3         Unnamed: 4 van der Waals  \
# 0        NaN        NaN     Avg.  Std. Dev.  Std. Err. of Mean          Avg.
# 1    LYS   1  R LYS   1        0          0                  0             0
# 2    GLY   2  R GLY   2        0          0                  0       -0.0002
# 3    GLY   3  R GLY   3        0          0                  0       -0.0002
# 4    TYR   4  R TYR   4        0          0                  0       -0.0012
# ..       ...        ...      ...        ...                ...           ...
# 372  TRP 372  R TRP 372        0          0                  0       -0.0004
# 373  LEU 373  R LEU 373        0          0                  0       -0.0006
# 374  ASN 374  R ASN 374        0          0                  0             0
# 375  SER 375  R SER 375        0          0                  0       -0.0002
# 376  LIG 376  L LIG   1        0          0                  0      -32.6958
#
# ...

# %% [markdown]
# ## We will drop any residues that has no contribution to the biding of the small molecule, which in this case is a NaN. You may want head to https://stackoverflow.com/questions/13413590/how-to-drop-rows-of-pandas-dataframe-whose-value-in-a-certain-column-is-nan for more pandas skill.

# %%
df1 = df[df.nonpolar != '0']
df1
# Out:
#      Residue   Location Internal Unnamed: 3         Unnamed: 4  \
# 0        NaN        NaN     Avg.  Std. Dev.  Std. Err. of Mean
# 23   LEU  23  R LEU  23        0          0                  0
# 24   GLY  24  R GLY  24        0          0                  0
# 25   TRP  25  R TRP  25        0          0                  0
# 26   GLY  26  R GLY  26        0          0                  0
# 28   PHE  28  R PHE  28        0          0                  0
# 29   SER  29  R SER  29        0          0                  0
# 30   THR  30  R THR  30        0          0                  0
# 31   VAL  31  R VAL  31        0          0                  0
# 33   LEU  33  R LEU  33        0          0                  0
# 44   ALA  44  R ALA  44        0          0                  0
# 46   LYS  46  R LYS  46        0          0                  0
# 61   GLU  61  R GLU  61        0          0                  0
# 65   LEU  65  R LEU  65        0          0                  0
# ...

# %%
df1.to_csv('structure.csv')

# %%
# Import the necessary modules
import matplotlib.pyplot as plt
import pandas as pd


# Initialize the lists for X and Y
data = pd.read_csv('/content/structure.csv')

df = pd.DataFrame(data)

X = list(df.iloc[:, 0])
Y = list(df.iloc[:, -3])

# Plot the data using bar() method
plt.bar(X, Y, 20, 10, color='g')
plt.title("Free energy decomposition")
plt.xlabel("residue ID")
plt.ylabel("Free energy per residue")

# Show the plot

plt.show()

# %% [markdown]
# Next the txt file will be save as a csv file, then import back again, to beautify the structure.

# %%
df3.to_csv('structure.csv')
